# %% [markdown]
# #                             Capstone Project - The Battle of Neighborhoods 1

# %% [markdown]
#    ## Table of contents
#
#
# 1. Introduction: Business Problem
# 2. Data

# %% [markdown]
# ## 1. Introduction: Business Problem

# %% [markdown]
# Opening up a restaurant is an entrepreneur’s dream or passion. To share the joy with patrons who end uprelishing the ambience, food and services is fulfilment of its own.
# However, only the owner knows what all efforts they have put in before opening up a restaurant. Developing and executing a solid business strategy for the restaurant is
# extremely important inorder to make the business successful.
#
# A perfect location has always been its major issue. Restaurants in heavily populated suburban areas or major cities face heavy competition.To overcome this issue,one should need a Data scientist who can analysis all the loactions of a particular city to open up a restaurant which can give proper business to the client.
#
# In this case, I have chosen city London. We will consider an enterpreneur or a business man our client, who wish to open up a restaurant in London.we will predict some perfect locations for his business along with some general idea of cuisines for each particular location.

# %% [markdown]
# ## 2. Data

# %% [markdown]
# #### Getting started
#
# The first thing you need to do is put a system in place for collecting area data through every channel possible. This should include List of areas of London "https://en.wikipedia.org/wiki/List_of_areas_of_London " or List of London boroughs "https://en.wikipedia.org/wiki/List_of_London_boroughs " or some where this can help "https://en.wikipedia.org/wiki/Wikipedia:WikiProject_London "; as long as you’re collecting data, you’re on the right path. After that, we will need some more data carrying the number of restaurants in london,probably this can help "https://foursquare.com/holden_cfield/list/london-restaurants ".
#
# #### Make the data work for you
#
# Once you’ve collected as much data as possible, it’s time to put that data to work for you. First and foremost, this requires that you ensure the data is “clean”—removing corrupt or inaccurate records, and enabling your machine to process the data. It can be quite tedious and labor-intensive, but is absolutely vital. As the saying goes: “Bad data in. Bad data out.”
#
# After cleaning the data you need to do an exploratory data analysis (EDA) to identify high-level trends that you can examine further with specific models and algorithms. From there, you need to run and re-run your data against these models and algorithms to identify patterns and extract insights that may not be visible to the human eye. And then you rinse and repeat, gaining deeper and more valuable insights as the process goes on.
